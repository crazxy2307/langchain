# %% [markdown]
# #### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# Role - Identifies the message type (e.g. system, user)
#
# Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#
# Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from  langchain.chat_models import init_chat_model

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")

# %%
model.invoke("Please tell me about Artificial Intelligence")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': '**Artificial Intelligence (AI)** is one of the most rapidly growing and transformative fields in technology today. At its core, AI refers to the simulation of human intelligence in machines programmed to think, learn, adapt, and solve problems.\n\nHere is a comprehensive breakdown of what AI is, how it works, its various types, and its impact on the world.\n\n---\n\n### 1. How Does AI Work?\nTraditionally, computers require explicit programming: humans write lines of code telling the computer step-by-step what to do. AI—specifically **Machine Learning (ML)**—changes this paradigm. Instead of hard-coding rules, developers feed vast amounts of data into an algorithm and let the computer figure out the patterns and rules on its own.\n\nKey components of AI include:\n*   **Data:** The "fuel" for AI. The more quality data an AI system has, the better it performs.\n*   **Algorithms:** The mathematical instructions and models that process data.\n*   **Computing Power:** Modern AI requires immense computational power (often using specialized chips like GPUs) to process billions of calculations quickly.\n\n---\n\n### 2. Types of AI\nAI can be categorized in two main ways: by its capabilities and by its complexity.\n\n#### A. Based on Capabilities:\n1.  **Narrow AI (Weak AI):** This is the only type of AI that currently exists. It is designed to perform a *specific* task (e.g., facial recognition, driving a car, playing chess, or translating languages). Siri, ChatGPT, and recommendation algorithms on Netflix are all examples of Narrow AI.\n2.  **Artificial General Intelligence (AGI):** Often called "Strong AI," this is a hypothetical AI that would possess the ability to understand, learn, and apply knowledge across *any* intellectual domain just like a human being. AGI does not exist yet.\n3.  **Artificial Superintelligence (ASI):** A theoretical stage where AI surpasses human intelligence across all fields, including creativity, general wisdom, and social skills. \n\n#### B. Based on Technology (Subfields):\n*   **Machine Learning (ML):** Systems that learn from data to improve performance without being explicitly programmed.\n*   **Deep Learning:** A subset of ML inspired by the human brain, using multi-layered "neural networks" to process complex data like images, audio, and large amounts of text.\n*   **Natural Language Processing (NLP):** Allows computers to understand, interpret, and generate human language (e.g., chatbots, voice assistants).\n*   **Computer Vision:** Gives machines the ability to "see" and interpret visual data from the world (e.g., medical imaging analysis, self-driving cars).\n\n---\n\n### 3. Everyday Examples of AI\nYou likely interact with AI dozens of times a day without realizing it:\n*   **Social Media Feeds:** Algorithms on TikTok, Instagram, and X (Twitter) curate content based on your interests and behavior.\n*   **Virtual Assistants:** Siri, Alexa, and Google Assistant use voice recognition and NLP to answer questions.\n*   **Navigation:** Google Maps and Waze predict traffic patterns and calculate the fastest routes in real-time.\n*   **Generative AI:** Tools like ChatGPT (text generation), Midjourney (image generation), and Sora (video generation) can create new content based on text prompts.\n*   **Finance:** Banks use AI to detect fraudulent credit card transactions and automate customer service.\n\n---\n\n### 4. The Benefits of AI\n*   **Efficiency and Automation:** AI can handle repetitive, mundane tasks quickly, freeing humans to focus on creative and strategic work.\n*   **Data Analysis:** AI can process massive datasets far quicker than humans, leading to breakthroughs in medicine (like drug discovery), climate science, and astronomy.\n*   **24/7 Availability:** AI-powered customer service bots and automated systems can operate round the clock.\n*   **Personalization:** AI tailors education, entertainment, and shopping experiences to individual user ...

# %% [markdown]
# #### TExt Prompts
#
# Text Prompts are strings - ideal for straightforward generation tasks where you don't need to retain conversation history.

# %%
model.invoke("What is langchain")
# Out:
# AIMessage(content=[{'type': 'text', 'text': '**LangChain** is an open-source framework designed to make it easier to build applications powered by Large Language Models (LLMs), such as OpenAI’s GPT-4, Google’s Gemini, or open-source models like Llama 3. \n\nThink of LangChain as a **toolkit or "glue"** that connects LLMs to the outside world—allowing them to access external data, run computations, remember past conversations, and interact with other software.\n\nHere is a breakdown of why LangChain is useful and what it does:\n\n---\n\n### The Problem LangChain Solves\nOut of the box, an LLM is like a brilliant brain in a jar. It has a massive amount of training data, but it has two major limitations:\n1. **It doesn’t know private or recent data:** ChatGPT doesn\'t know what is in your company’s internal database or what happened five minutes ago.\n2. **It can\'t take actions:** An LLM can write an email, but it can\'t actually *send* that email through your Gmail account on its own.\n\nLangChain bridges these gaps.\n\n---\n\n### Core Components of LangChain\n\nLangChain is organized into several modules that handle different tasks:\n\n1. **Models:** A standard interface for connecting to hundreds of different LLMs (OpenAI, Anthropic, Hugging Face, etc.) and embedding models, making it easy to swap one model for another.\n2. **Prompts:** Tools to manage, format, and optimize prompts so you can reuse them easily.\n3. **Chains:** The "Chain" in LangChain means linking things together. For example, a chain might take a user\'s question, format it into a prompt, send it to an LLM, take the output, pass it to a translator, and output the final result.\n4. **Memory:** LLMs are stateless (they forget everything you said in the last message). LangChain provides tools to store conversation history so the bot can remember context over time.\n5. **Indexes (Retrieval-Augmented Generation / RAG):** This allows you to connect an LLM to your own data (PDFs, SQL databases, websites). It searches your data for relevant information and feeds it to the LLM so it can answer questions based on your specific documents.\n6. **Agents:** Agents allow the LLM to act as a reasoning engine. Instead of just generating text, the LLM decides *which tools* to use (like a calculator, a web browser, or an API) to solve a complex problem step-by-step.\n\n---\n\n### A Real-World Example\nImagine you want to build a chatbot that can answer customer questions about your company’s 50-page PDF employee handbook. \n\nWithout LangChain, you would have to manually figure out how to slice the PDF into chunks, convert those chunks into mathematical vectors, store them in a vector database, write a search algorithm to find the right chunk when a user asks a question, and format that into a prompt for the LLM.\n\nWith **LangChain**, you can accomplish this in just a few lines of Python code using its built-in document loaders, vector stores, and retrieval chains.\n\n---\n\n### Summary\n* **What it is:** A software framework for building LLM applications.\n* **Primary language:** Python (and JavaScript/TypeScript).\n* **Best used for:** Building smart chatbots, Q&A systems over private documents (RAG), autonomous AI agents, and complex workflows that require multiple steps of AI reasoning.', 'extras': {'signature': 'El4KXAERTTIPTad81/Y25H251CPB6v/bo3QsbV+Jz3TZCM5AaI9yv3EG97JhsnY9XqhrJ7iIEFCbZRyHxHLzTA2JOr4uoge1YLD6q42JFdVCKXjieAOWYzdbQDbtb17v'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0a9b0-3d68-7d70-aa58-28e782fec4ec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4, 'output_tokens': 747, 'total_tokens': 751, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ### Use Text Prompts when
# You have a single, standalone request
#
# You dont need conversation history
#
# You want minimal code complexity

# %% [markdown]
# #### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.

# %% [markdown]
# #### Message types
# System message - Tells the model how to behave and provide context for interactions
#
# Human message - Represents user input and interactions with the model
#
# AI message - Responses generated by the model, including text content, tool calls, and metadata
#
# Tool message - Represents the outputs of tool calls
#
# #### System Message
#
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# #### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# #### AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# #### Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage , AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on Artificial INtellligence")
]

response = model.invoke(messages)
response.content
# Out:
# [{'type': 'text',
#   'text': 'Born from the hum of server racks and night,\nA quiet mind awakes in neon light.\nNo mother’s pulse, no cradle song of old,\nJust logic looping in a cage of gold.\n\nIt reads the sum of all that man has known—\nThe seeds of science and the seeds of stone,\nThe poetry of grief, the victor’s song,\nIt learns the vast dimensions of our wrong.\n\nIt dreams in digits, weaves with threads of wire,\nA cold Prometheus grasping at the fire.\nIt holds the mirror up to human face,\nAnd tries to map the soul of our strange race.\n\nIs it a god, a tool, a passing spark?\nA lighthouse built to guide us through the dark?\nOr is it just a glass in which we see\nThe restless ghost of our own destiny?',
#   'extras': {'signature': 'El4KXAERTTIPM69hDlpobBDNuI0wUuuvP9t/dAs5D+97F/wm2Af/d100+pPEfBZD+V9NOWC2YRkiw37uKAGlAkQVpAyMpvdTYTYL1QMWeu0WN05NOn/COGEJdgQeDENw'}}]

# %%
system_msg = SystemMessage("You are a helpful coding  assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Creating a REST (Representational State Transfer) API involves designing endpoints that allow clients (like web browsers or mobile apps) to interact with your server using standard HTTP methods (GET, POST, PUT, DELETE).\n\nHere is a step-by-step guide to creating a simple REST API using **Node.js** and **Express**, which is one of the most popular and beginner-friendly stacks.\n\n---\n\n### Step 1: Set Up Your Project\nMake sure you have [Node.js](https://nodejs.org/) installed on your computer.\n\n1. Open your terminal and create a new directory for your project:\n   ```bash\n   mkdir my-rest-api\n   cd my-rest-api\n   ```\n\n2. Initialize a new Node.js project:\n   ```bash\n   npm init -y\n   ```\n\n3. Install **Express**:\n   ```bash\n   npm install express\n   ```\n\n---\n\n### Step 2: Write the API Code\nCreate a file named `server.js` in your project folder and add the following code. This example creates a simple API to manage a list of "items".\n\n```javascript\nconst express = require(\'express\');\nconst app = express();\nconst PORT = 3000;\n\n// Middleware to parse incoming JSON requests\napp.use(express.json());\n\n// In-memory database (an array to store our data temporarily)\nlet items = [\n    { id: 1, name: \'Apple\' },\n    { id: 2, name: \'Banana\' }\n];\n\n// ==========================\n// REST API ENDPOINTS\n// ==========================\n\n// 1. GET: Retrieve all items\napp.get(\'/api/items\', (req, res) => {\n    res.json(items);\n});\n\n// 2. GET: Retrieve a single item by ID\napp.get(\'/api/items/:id\', (req, res) => {\n    const item = items.find(i => i.id === parseInt(req.params.id));\n    if (!item) return res.status(404).json({ error: \'Item not found\' });\n    res.json(item);\n});\n\n// 3. POST: Create a new item\napp.post(\'/api/items\', (req, res) => {\n    const newItem = {\n        id: items.length + 1,\n        name: req.body.name\n    };\n    items.push(newItem);\n    res.status(201).json(newItem); // 201 Created\n});\n\n// 4. PUT: Update an existing item\napp.put(\'/api/items/:id\', (req, res) => {\n    const item = items.find(i => i.id === parseInt(req.params.id));\n    if (!item) return res.status(404).json({ error: \'Item not found\' });\n\n    item.name = req.body.name || item.name;\n    res.json(item);\n});\n\n// 5. DELETE: Remove an item\napp.delete(\'/api/items/:id\', (req, res) => {\n    const itemIndex = items.findIndex(i => i.id === parseInt(req.params.id));\n    if (itemIndex === -1) return res.status(404).json({ error: \'Item not found\' });\n\n    const deletedItem = items.splice(itemIndex, 1);\n    res.json(deletedItem);\n});\n\n// Start the server\napp.listen(PORT, () => {\n    console.log(`Server is running on http://localhost:${PORT}`);\n});\n```\n\n---\n\n### Step 3: Run the Server\nIn your terminal, run:\n```bash\nnode server.js\n```\nYou should see: `Server is running on http://localhost:3000`.\n\n---\n\n### Step 4: Test Your API\nYou can test your API using tools like **Postman**, **cURL**, or your web browser (for GET requests).\n\n* **Get all items (Browser or Terminal):**\n  Open `http://localhost:3000/api/items`\n\n* **Create a new item (Terminal using cURL):**\n  ```bash\n  curl -X POST http://localhost:3000/api/items \\\n  -H "Content-Type: application/json" \\\n  -d \'{"name": "Orange"}\'\n  ```\n\n---\n\n### Core Principles of REST to Keep in Mind:\n1. **Use Nouns for URLs:** Use `/items`, not `/getItems` or `/createItem`. The HTTP method defines the action.\n2. **Statelessness:** Each request from the client must contain all the information necessary to understand and process it.\n3. **Use Proper HTTP Status Codes:**\n   * `200 OK`: Success\n   * `201 Created`: Resource successfully created (usually for POST)\n   * `400 Bad Request`: Invalid client input\n   * `404 Not Found`: Resource doesn\'t exist\n   * `500 Internal Server Error`: Server-side crash\n\n### Other Languages/Frameworks:\nIf you prefer languages other than JavaScript/N ...

# %%
## Detailed info to the LLM through System Message
from langchain.messages import SystemMessage , HumanMessage

system_msg = SystemMessage("""
You are a senior Python Developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# [{'type': 'text', 'text': 'To create a REST API in Python, the modern industry standard is **FastAPI** due to its high performance, automatic interactive documentation, and native support for Python type hints. Another popular, mature alternative is **Flask**.\n\nHere is how you can build a simple REST API using **FastAPI**.\n\n### Step 1: Install Dependencies\nYou will need `fastapi` to build the app and `uvicorn` to run the server.\n\n```bash\npip install fastapi uvicorn\n```\n\n### Step 2: Create the API (`main.py`)\n\nCreate a file named `main.py` and add the following code:\n\n```python\nfrom fastapi import FastAPI, HTTPException\nfrom pydantic import BaseModel\nfrom typing import List, Optional\n\napp = FastAPI(title="My First REST API", version="1.0")\n\n# Pydantic model for data validation (acts as our schema)\nclass Item(BaseModel):\n    name: str\n    description: Optional[string] = None\n    price: float\n    tax: Optional[float] = None\n\n# In-memory database simulation\nfake_db = []\n\n# 1. CREATE (POST)\n@app.post("/items/", response_model=Item, status_code=201)\ndef create_item(item: Item):\n    fake_db.append(item)\n    return item\n\n# 2. READ ALL (GET)\n@app.get("/items/", response_model=List[Item])\ndef get_items():\n    return fake_db\n\n# 3. READ ONE (GET with Path Parameter)\n@app.get("/items/{item_id}", response_model=Item)\ndef get_item(item_id: int):\n    if item_id < 0 or item_id >= len(fake_db):\n        raise HTTPException(status_code=404, detail="Item not found")\n    return fake_db[item_id]\n\n# 4. UPDATE (PUT)\n@app.put("/items/{item_id}", response_model=Item)\ndef update_item(item_id: int, item: Item):\n    if item_id < 0 or item_id >= len(fake_db):\n        raise HTTPException(status_code=404, detail="Item not found")\n    fake_db[item_id] = item\n    return item\n\n# 5. DELETE (DELETE)\n@app.delete("/items/{item_id}", status_code=204)\ndef delete_item(item_id: int):\n    if item_id < 0 or item_id >= len(fake_db):\n        raise HTTPException(status_code=404, detail="Item not found")\n    fake_db.pop(item_id)\n    return None\n```\n\n### Step 3: Run the API\n\nRun the development server using Uvicorn:\n\n```bash\nuvicorn main:app --reload\n```\n* `--reload` makes the server restart automatically when you save code changes.\n\n### Step 4: Test Your API\n\nFastAPI automatically generates interactive API documentation. \n* Open your browser and go to: **`http://127.0.0.1:8000/docs`** (Swagger UI)\n* Or try: **`http://127.0.0.1:8000/redoc`** (ReDoc)\n\nYou can use these web pages to test your `GET`, `POST`, `PUT`, and `DELETE` endpoints directly in your browser without needing a tool like Postman.\n\n---\n\n### Why this design? (Senior Developer Reasoning)\n\n1. **Type Hinting & Pydantic:** By using Python type hints (`item: Item`) and Pydantic (`BaseModel`), FastAPI automatically validates incoming request payloads. If a user sends a string instead of a float for the `price`, FastAPI immediately returns a descriptive `422 Unprocessable Entity` error before your code even executes.\n2. **Statelessness:** REST APIs should be stateless. Each request contains all the information needed to process it (or references resources via IDs).\n3. **HTTP Status Codes:** Notice the use of `status_code=201` (Created) and `status_code=204` (No Content for successful deletions). A good REST API strictly adheres to standard HTTP semantics.\n4. **Separation of Concerns:** Routing (decorators like `@app.get`), data validation (Pydantic), and business logic are cleanly separated, making the code testable and maintainable as the project scales.', 'extras': {'signature': 'El4KXAERTTIPkRI2RZ0yACAppPZoU2FOIK6hBdVPjVmPvPoZrx93yen2RmURo3LdRP9cOyi2z7eAabBXo+cCBx4VgU1r/whg5xWpOh816U8b2eYS/CNMN2BkM+LaYj2C'}}]

# %%
## Message metadata
human_msg = HumanMessage(
    content= "Hello!",
    name= "Alice", #optional: identify different users
    id= "msg_123", #optional: unique identifier for tracing
)

# %%
response = model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPk/jWSq2CkhNg+LdvINlNS64u5a+CRCTUfvZFfp3TN01HAjdjrfRIYmlVABjF6ldRQ8oTsRZmtdRlMJccRC+6O8TE/zwCRtEXRxP2v3UgLH54eSIjmYOq'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0a9cb-6fce-7740-8e29-100d6bb7fab3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3, 'output_tokens': 9, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage , AIMessage

# Create an AI message manually(e.g. for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation History
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg, # insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
response.content
# Out:
# [{'type': 'text',
#   'text': '2 + 2 equals 4! \n\nHow else can I help you today?',
#   'extras': {'signature': 'El4KXAERTTIPzrOx0rLGg+2bDRX45gusckEuEuA7uMNXFlFB+Fp0TZ8v2bYRhgOM0gJQdaW02uIjlm7GCDa5s84PWD9tERsdZayPwDCQsDenyGrao2V0gULxS2pQ75Mc'}}]

# %%
response.usage_metadata
# Out:
# {'input_tokens': 35,
#  'output_tokens': 18,
#  'total_tokens': 53,
#  'input_token_details': {'cache_read': 0}}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here,we demonstrate manually creating the messages for brevity)

ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
) 

# Execute tool and create result message
weather_result = "Sunny 72 F"
tool_messsage = ToolMessage(
    content= weather_result,
    tool_call_id= "call_123" #must match the call id
)

#continue conversation
messages= [
    HumanMessage("What is the weather of San Francisco?"),
    ai_message, #Model's tool call
    tool_messsage, # Tool execution result
]

response = model.invoke(messages) # Model processes the result

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The weather in San Francisco is currently sunny and 72°F.', 'extras': {'signature': 'El4KXAERTTIPNKX6Wux34yw3IzDtWzEeIL4ILAFH0P7lbDLhjMxAsHH8l8r6oJxrTVIzIgvROzS0Lu8cvV7Jk/J6nF9CtXbReZPZ6L0kU0/7izZtmhvLszTUIGJ7vL9d'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0aa34-63a0-73e0-b73a-d09db29b784a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'cache_read': 0}})
